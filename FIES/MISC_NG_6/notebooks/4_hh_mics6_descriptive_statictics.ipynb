# %% [markdown]
# # Descriptive Summary Statistics

# %% [markdown]
# ### Table 1: Summary of Food Insecurity Measures and Indicators. (weighted using the household sampling weight).

# %%
fies_cols1= list(df2.loc[:, "WORRIED": "WHLDAY"].columns)
fies_cols2 = list(
    df2[
    ["prob_mod_sev", "prob_sev", "fies_score","FI_mod_sev", "FI_sev",
     "food_insecure_1_0", "food_insecure_4_8", "food_insecure_7_8",]].columns
)

fies_cols = fies_cols1 + fies_cols2 + ["hhweightmics"]
fies_indicator_df = df2[fies_cols] 
fies_indicator_df.sample(2)
# Out:
#        WORRIED  HEALTHY  FEWFOOD  SKIPPED  ATELESS  RANOUT  HUNGRY  WHLDAY  \
# 29248        0        0        0        0        0       0       0       0
# 7389         1        0        0        1        1       0       0       0
#
#        prob_mod_sev  prob_sev  fies_score  FI_mod_sev  FI_sev  \
# 29248         0.000       0.0           0           0       0
# 7389          0.284       0.0           3           1       0
#
#        food_insecure_1_0  food_insecure_4_8  food_insecure_7_8  hhweightmics
# 29248                  0                  0                  0      4.600347
# 7389                   1                  0                  0      0.539299

# %%
fies_indicator_df.iloc[:,:-1].describe().T[["count", "mean", "std"]].round({"mean": 2, "std": 2})
# Out:
#                      count  mean   std
# WORRIED            10680.0  0.76  0.43
# HEALTHY            10680.0  0.72  0.45
# FEWFOOD            10680.0  0.72  0.45
# SKIPPED            10680.0  0.64  0.48
# ATELESS            10680.0  0.69  0.46
# RANOUT             10680.0  0.57  0.49
# HUNGRY             10680.0  0.50  0.50
# WHLDAY             10680.0  0.29  0.45
# prob_mod_sev       10680.0  0.68  0.42
# prob_sev           10680.0  0.27  0.33
# fies_score         10680.0  4.87  2.94
# FI_mod_sev         10680.0  0.81  0.39
# FI_sev             10680.0  0.65  0.48
# food_insecure_1_0  10680.0  0.81  0.39
# food_insecure_4_8  10680.0  0.71  0.46
# food_insecure_7_8  10680.0  0.41  0.49

# %% [markdown]
# * The result presents the weighted pooled summary statistics and shows that 68% percent of households experienced moderate or severe food insecurity. About 81 percent of households report experiencing at least one of the eight dimensions of food insecurity that constitute the FIES

# %%
# Weighted Descriptive statistics of all the continuous variables... mean, std, se
# -=============Descritptives Tables ==========
# Table 2: Characteristics of the study population by food security status among urban households, MICS6a
# Table 3: Estimated total number of houshold that are (i) moderately or severely food insecure and (ii) severely food insecure and 
# Table 4: average incidence of (i) moderate or severe food insecurity and (ii) severe food insecurity among the urban household (by zone)

# ==============Regressions=============
# Table 5: Prevalence of food insecurity by zone 
# Table 6: Prevalence of food insecurity by gender of household head and zone.

# %% [markdown]
# <hr>
# <div>
#     <a href="./3_hh_mics6_modelling.ipynb">
#         <button style="float: right;">&#8594; Modelling Notebook </button>
#     </a>
#     <a href="./3_hh_mics6_eda.ipynb">
#         <button>&#8592; EDA Notebook</button>
#     </a>
# </div>
# <hr>
