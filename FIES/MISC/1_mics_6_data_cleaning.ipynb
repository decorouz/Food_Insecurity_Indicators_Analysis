# %% [markdown]
# # Determinants of Household Food Insecurity Amongst Urban Household in Nigeria Using MICS6 Dataset:
# ### A multilevel multinorminal logistic regression  and mixed effect analysis.
#
#
# **Objectives**
# 1. To assess factors associated with household food insecurity in Nigeria

# %% [markdown]
# ### Data source and study population
# This study is based on quantitative cross-sectional data derived from the Nigeria 2021 Multiple Indicator Cluster Survey (MICS6), which is a nationally representative survey that collects sociodemographic and health indicators from both household, males and females aged 15–49 years.
#
# The survey utilized a multistage stratified cluster sampling approach that employed a probability proportional to size to select enumeration areas in the first stage based on the 2006 Population and Housing Census of the Federal Republic of Nigeria (NPHC). In the second stage, 20 households were randomly selected within each enumeration area.

# %% [markdown]
# ### Load the required libraries

# %%
# Load the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl

import functools
import operator
pd.set_option("display.max_columns", 400)

# %% [markdown]
# #### Read the data into a dataframe

# %%
# Household information panel
hh = pd.read_spss("../../data/mics6ng/hh.sav")

# %%
# Women(15-49 years)
wm = pd.read_spss("../../data/mics6ng/wm.sav")

# %%
# Women(15-49 years)
mn = pd.read_spss("../../data/mics6ng/mn.sav")

# %%
# Data collected at the children's level 
ch = pd.read_spss("../../data/mics6ng/ch.sav")

# %% [markdown]
# ## **Data Pre-Processing Pipeline.**

# %% [markdown]
# ### MISC data files
# Each of the data files contains data collected in the relevant questionnaires. Some variables considered to be of critical importance for the analysis are included in all data files, regardless of the questionnaire used to collect the information.
#
# All information required for this analysis is not present in one single data file. There is need for `MICS data` files to be combined or merged.

# %%
# Turn the column names to lowercase
def rename_colnames_tolower(df):
    """Rename the column names to lower case"""
    return df.rename(str.lower, axis="columns")

# %% [markdown]
# ### **Select Relevant Variables from `hh.sav`**
#
# **Variables selection from `hh.sav` data file**
#
#
# * Format the variables names to lowercase.
# * Identify the relevant columns.
# * Create a dictionary of column names.
# * Subset with the selected variables
# * Filter the household data by consent `hh12`
# * Filter by the case source (survey): **MICS** or NICS `survey`

# %%
# Turn to lower the column names
hh = rename_colnames_tolower(hh)

# household columns
hh_cols = ["hh1", "hh2", "hh6","hh7", "zone", 
           # consent
           "hh12",
           # "hh8", "
           "hh48", "hh49", "hh50", "hh51","hh52",
           "hhsex", "hhage", "helevel", "hc14"]


# Household head have and have not
hh_livestock_cols = ["hc15", "hc16", "hc17"] + [col for 
                                        col in hh.columns if col.startswith("hc18")]

# Household worried about not having enough food (FIES)
hh_fies_cols = [col for col in hh.columns if col.startswith("fe")]


# Source of water 
hh_water_cols = ["ws1", "ws2", "ws3"]

#Sanitation
hh_toilet_cols = ["ws11", "ws14", "ws15", "ws16"]


# hh wealth index columns
hh_windex_cols = ["windex5mics","windex5umics"]


# hh survey design columns
hh_meta_data_cols = ["hhweightmics", "psu", "stratum", "survey"]


hh_final_cols = functools.reduce(operator.add, [hh_cols, hh_windex_cols, 
                                                hh_livestock_cols, hh_water_cols, 
                                                hh_fies_cols, hh_meta_data_cols])

print(f"Total number of variables selected: {len(hh_final_cols)}")
# Out:
# Total number of variables selected: 67

# %%
# hh columns to rename
hh_dict = {
    "ws11": "toilet_type",
    "ws14": "toilet_location",
    "ws15": "toilet_num_hh_using",
    "ws16": "toilet_shared",
    "ws1": "water_source",
    "ws2": "other_water_source",
    "ws3": "water_source_location",
    "hh6": "area", 
    "hh7": "state",
    "hh12": "consent",
    "hc14": "hh_own_dwelling",
    "hc15": "hh_agricultural_land",
    "hc16": "hh_ag_land_size",
    "hc17": "hh_own_animal",
    "hh48": "hh_members_num",
    "hh49" : "num_of_women_15_49",
    "hh50" : "num_of_men_15_49",
    "hh51" : "num_under_5_child",
    "hh52" : "num_5_17_child", 
    # Wealth index
    "windex5umics": "urban_wi_quintile_mics",
    "windex5mics": "wi_quintile_mics",

    
}

# %%
# Subset the dataframe
hh_subset = hh[hh_final_cols]

# %%
hh_subset = hh_subset.rename(columns=hh_dict)

# %%
# Filter the household data by consent consent
print("Dataframe shape filter by consent", hh_subset.shape)
hh_subset = hh_subset.loc[hh_subset["consent"] == "YES"]
print("Dataframe shape after filter by consent", hh_subset.shape)
# Out:
# Dataframe shape filter by consent (41532, 67)
# Dataframe shape after filter by consent (39632, 67)

# %%
hh_subset["survey"].value_counts()
# Out:
# survey
# MICS    33631
# NICS     6001
# Name: count, dtype: int64

# %%
# Filter by the case source (survey): MICS or NICS survey
print("Dataframe shape filter by MICS", hh_subset.shape)
hh_subset = hh_subset.loc[hh_subset["survey"] == "MICS"].reset_index(drop=True)
print("Dataframe shape after filter by MICS", hh_subset.shape)
# Out:
# Dataframe shape filter by MICS (39632, 67)
# Dataframe shape after filter by MICS (33631, 67)

# %% [markdown]
# **FIES `(fe1 - fe8c)`**
#
# * Select the variables that contains the prevalence of food insecurity experience scale.
# * Transform the values to numerica. That is map {Yes:1, No:0}.
# * Save the resulting variables to dataframe to perform `Ransch analysis`

# %%
# Household worried about not having enough food (FIES)
import re

# Select primary fies question only
fies_cols = [col for col in hh_subset.columns if re.search(r'^(fe)\d+$', col)]

hh_subset[fies_cols] = hh_subset[fies_cols].apply(lambda x:x.str.upper() == "YES").astype("int8")

hh_subset = hh_subset.assign(fies_score = hh_subset[fies_cols].sum(axis=1))

#
# Create a list of columns including specific columns ("hh1", "hh2", "area", "zone", "hhweightmics") 
# and additional columns from hh_subset that start with "fe"
fies_cols = ["hh1", "hh2", "area", "zone", "hhweightmics"] + [col for col in hh_subset.columns if col.startswith("fe")]

# Select the specified columns from the hh_subset dataframe and save it to a new dataframe fies_df
fies_df = hh_subset[fies_cols]

# Save the fies_df dataframe to a CSV file named "fies_df.csv" without including row indices
fies_df.to_csv("datasets/hh_fies_df.csv", index=False)

# %%
hh_subset.drop(columns=hh_fies_cols, axis=1, inplace=True)

hh_subset.head(2)
# Out:
#    hh1  hh2   area state        zone consent  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East     YES             4.0
# 1  1.0  2.0  URBAN  ABIA  South East     YES             2.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 2.0               0.0                0.0             1.0
#
#     hhsex  hhage           helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0           Primary            RENT           Fourth
# 1  Female   45.0  Senior secondary            RENT           Fourth
#
#   urban_wi_quintile_mics hh_agricultural_land hh_ag_land_size hh_own_animal  \
# 0                 Middle                   NO             NaN            NO
# 1                 Second                   NO             NaN            NO
#
#   hc18a hc18b hc18c hc18d hc18e hc18f hc18g hc18h hc18i hc18k hc18l hc18m  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#   hc18n          water_source other_water_source water_source_location  \
# 0   NaN  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 1   NaN  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
#
#    hhweightmics  psu  stratum survey  fies_score
# 0       0.61955  1.0      1.0   MICS           7
# 1       0.61955  1.0      1.0   MICS           6

# %% [markdown]
# **Agricultural Land `hh_ag_land_size` and `hh_agricultural_land`**
#
# * Replace NaN values with 0.0 in `hh_ag_land_size` if `hh_agricultural_land` is 'NO'

# %%
# Create a boolean mask for rows where 'hh_agricultural_land' is 'NO'
mask = hh_subset['hh_agricultural_land'] == 'NO'

# Replace NaN with 0 in 'hh_ag_land_size' where the mask is True
hh_subset.loc[mask, 'hh_ag_land_size'] = hh_subset.loc[mask, 'hh_ag_land_size'].fillna(0)

hh_subset.head(2)
# Out:
#    hh1  hh2   area state        zone consent  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East     YES             4.0
# 1  1.0  2.0  URBAN  ABIA  South East     YES             2.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 2.0               0.0                0.0             1.0
#
#     hhsex  hhage           helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0           Primary            RENT           Fourth
# 1  Female   45.0  Senior secondary            RENT           Fourth
#
#   urban_wi_quintile_mics hh_agricultural_land hh_ag_land_size hh_own_animal  \
# 0                 Middle                   NO             0.0            NO
# 1                 Second                   NO             0.0            NO
#
#   hc18a hc18b hc18c hc18d hc18e hc18f hc18g hc18h hc18i hc18k hc18l hc18m  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#   hc18n          water_source other_water_source water_source_location  \
# 0   NaN  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 1   NaN  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
#
#    hhweightmics  psu  stratum survey  fies_score
# 0       0.61955  1.0      1.0   MICS           7
# 1       0.61955  1.0      1.0   MICS           6

# %% [markdown]
# **Household Livestock**
#
# * Select the household with livestock variables
# * Create a new variable `hh_ls_num`. The sum of livestock per household
# *

# %%
# Create livestock count variables
# by summing up all the livestock in the household

# %%
# For those who respond hc17 is No replace hh_ls_cols with 0

cols_to_modify = [col for col in hh_subset.columns if col.startswith("hc18")]

mask = hh_subset["hh_own_animal"].isin(["NO", "NO RESPONSE"])
hh_subset.loc[mask, cols_to_modify] = hh_subset.loc[mask, cols_to_modify].fillna(0.0)

# Get the livestock columns and change as types from category to int. 
# Run this code onces.
hh_ls = hh_subset[cols_to_modify].apply(lambda x:x.cat.codes)

# Add a new column to indication the total livestock per hh
hh_subset["hh_ls_num"] = hh_ls.sum(axis=1)

# 
ls_cols = ["hh_own_animal", "hh1", "hh2", "hhsex", 
           "hh_own_dwelling", "hh_agricultural_land", 
           "hh_ag_land_size"] + \
        [col for col in hh_subset.columns if col.startswith("hc18")]

ls_df = hh_subset[ls_cols]

# Save data to csv
ls_df.to_csv("datasets/hh_livestock_dataset.csv", index=False)


# # Drop the other livestock columnes
hh_subset = hh_subset.drop(columns=cols_to_modify)

hh_subset.head()
# Out:
#    hh1  hh2   area state        zone consent  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East     YES             4.0
# 1  1.0  2.0  URBAN  ABIA  South East     YES             2.0
# 2  1.0  3.0  URBAN  ABIA  South East     YES             5.0
# 3  1.0  4.0  URBAN  ABIA  South East     YES             4.0
# 4  1.0  5.0  URBAN  ABIA  South East     YES             5.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 2.0               0.0                0.0             1.0
# 2                 1.0               0.0                2.0             1.0
# 3                 1.0               1.0                0.0             0.0
# 4                 1.0               0.0                0.0             1.0
#
#     hhsex  hhage           helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0           Primary            RENT           Fourth
# 1  Female   45.0  Senior secondary            RENT           Fourth
# 2    Male   41.0  Senior secondary             OWN           Fourth
# 3    Male   81.0              None             OWN           Middle
# 4    Male   63.0           Primary            RENT           Fourth
#
#   urban_wi_quintile_mics hh_agricultural_land hh_ag_land_size hh_own_animal  \
# 0                 Middle                   NO             0.0            NO
# 1                 Second                   NO             0.0            NO
# 2                 Middle                   NO             0.0           YES
# 3                Poorest                  YES             2.0           YES
# 4                 Middle                   NO             0.0            NO
#
#            water_source other_water_source water_source_location  \
# 0  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 1  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 2  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 3  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 4  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
#
#    hhweightmics  psu  stratum survey  fies_score  hh_ls_num
# 0       0.61955  1.0      1.0   MICS           7          0
# 1       0.61955  1.0      1.0   MICS           6          0
# 2       0.61955  1.0      1.0   MICS           5         30
# 3       0.61955  1.0      1.0   MICS           7        144
# 4       0.61955  1.0      1.0   MICS           7          0

# %% [markdown]
# ### **Select Relevant Columns from `mn.sav` Men (15-49 years of age)**
#
# * Format variables name to lowercase
# * Select variable of interest
# * Rename variables of interest
# * Filter by consent

# %%
# Turn to lower the column names
mn = rename_colnames_tolower(mn)

mn_cols = ["hh1", "hh2", "ln",
           "mwb4", "mwb5",
           "mmstatus","mma1",
           "mwage",
           "mls1", "mls2", "mls3", "mls4",
           "mwelevel",
           "survey", "mwm9"]

mn_dict = {
    "mwm9": "consent",
    "mls1": "mn_overall_happiness",
    "mls2": "mn_life_satisfaction",
    "mls3": "mn_life_satisfaction_last_year",
    "mls4": "mn_life_satisfaction_expectation",
    "mwb5": "mn_attended_sch",
    "mwelevel": "mn_education",
    "mmstatus": "mn_mstatus",
    "mma1": "mn_currently_married",
    "mwage": "mn_age_cat",
    "mwb4": "mn_age_yrs",
    
}

# Create a subset of the 'mn' DataFrame, 
# including only the columns specified in 'mn_cols'
mn_subset = mn[mn_cols]

# Rename the columns of mn_subset using the key-value pairs in mn_dict
mn_subset = mn_subset.rename(columns=mn_dict)


# Filter out records where consent is not "YES"
mn_subset = mn_subset[mn_subset["consent"] == "YES"].reset_index(drop=True)

# %%
mn_subset.shape
# Out:
# (17347, 15)

# %% [markdown]
# **Life Satisfaction `mn_life_satisfaction`**

# %%
mn_subset[["mn_life_satisfaction"]].value_counts(dropna=False)
# Out:
# mn_life_satisfaction
# 5                       3081
# 6                       2327
# 4                       2180
# 7                       2153
# 3                       1968
# 8                       1842
# 2                       1421
# 9                        860
# 1                        746
# 10                       631
# 0                        132
# NO RESPONSE                6
# Name: count, dtype: int64

# %% [markdown]
# * Replace the value "NO RESPONSE" with NaN
# * The variable doesn't include NaN values

# %%
# Replace "NO response" with NaN
mn_subset['mn_life_satisfaction'] = mn_subset['mn_life_satisfaction'].replace("NO RESPONSE", np.nan)

mn_subset['mn_life_satisfaction_num'] = mn_subset['mn_life_satisfaction'].astype(float)
# Out:
# /var/folders/v2/zgr5gbws4qd_qpb553947v7h0000gn/T/ipykernel_37129/6390347.py:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   mn_subset['mn_life_satisfaction'] = mn_subset['mn_life_satisfaction'].replace("NO RESPONSE", np.nan)

# %% [markdown]
# ### **Select Relevant Columns from `wm.sav`:  Women (15-49 years of age)**
#
# * Select variable of interest
# * Rename variables of interest
# * Filter by consent

# %%
# Select column of interest from wm.sav

wm = rename_colnames_tolower(wm)

wm_cols = ["hh1", "hh2", "ln",
           # "wm1", "wm2", "wm3",
           "wb4", "wm9",
           "wage", "wb5", "wb6a","welevel", 
           "ls1","ls2","ls3","ls4",
           "survey", "mstatus", 
           "ma1", 
           "windex5u",
           "wmweight", "stratum"]

wm_dicts  = {
    # "wm1": "w_cluster_num",
    # "wm2": "w_hh_num",
    # "wm3": "w_line_num",
    "wb4": "wm_age_yrs",
    "wm9": "consent",
    "ls1": "wm_overall_happiness",
    "ls2": "wm_life_satisfaction",
    "ls3": "wm_life_satisfaction_last_year",
    "ls4": "wm_life_satisfaction_expectation",
    "wage": "wm_age_cat",
    "wb5": "wm_attended_sch",
    "wb6a": "wm_level_education",
    "mstatus": "wm_mstatus",
    "ma1": "wm_currently_married",
     # Wealth index
    "windex5u": "urban_wi_quintile_mics",

}

# Create a subset of the 'wm' DataFrame, including only the columns specified in 'wm_cols'
wm_subset = wm.loc[:, wm_cols]

# Rename the columns of wm_subset using the key-value pairs in wm_dicts
wm_subset = wm_subset.rename(columns=wm_dicts)

# Filter out records where consent is not "YES"
wm_subset = wm_subset[wm_subset["consent"] == "YES"].reset_index(drop=True)

# %%
wm_subset.shape
# Out:
# (38813, 19)

# %%
wm_subset.head(2)
# Out:
#    hh1  hh2   ln  wm_age_yrs consent wm_age_cat wm_attended_sch  \
# 0  1.0  1.0  1.0        46.0     YES      45-49             YES
# 1  1.0  1.0  2.0        22.0     YES      20-24             YES
#
#   wm_level_education           welevel       wm_overall_happiness  \
# 0            PRIMARY           Primary           SOMEWHAT UNHAPPY
# 1   SENIOR SECONDARY  Senior secondary  NEITHER HAPPY NOR UNHAPPY
#
#   wm_life_satisfaction wm_life_satisfaction_last_year  \
# 0                    3                       WORSENED
# 1                    4                       WORSENED
#
#   wm_life_satisfaction_expectation survey                  wm_mstatus  \
# 0                           BETTER   MICS  Currently married/in union
# 1                           BETTER   MICS      Never married/in union
#
#      wm_currently_married urban_wi_quintile_mics  wmweight  stratum
# 0  YES, CURRENTLY MARRIED                 Middle  0.631645      1.0
# 1        NO, NOT IN UNION                 Middle  0.631645      1.0

# %% [markdown]
# **Live Satisfaction `wm_life_satisfaction`**

# %%
wm_subset['wm_life_satisfaction'].isna().sum()
# Out:
# 7

# %%
wm_subset['wm_life_satisfaction'].value_counts(dropna=False)
# Out:
# wm_life_satisfaction
# 5              7010
# 6              5517
# 7              5285
# 8              4959
# 10             4052
# 4              3831
# 9              3475
# 3              2364
# 2              1173
# 1               823
# 0               249
# NO RESPONSE      68
# NaN               7
# Name: count, dtype: int64

# %%
# Replace "NO RESPONSE" with NaN
wm_subset['wm_life_satisfaction'] = wm_subset['wm_life_satisfaction'].replace("NO RESPONSE", np.nan)
wm_subset['wm_life_satisfaction_num'] = wm_subset['wm_life_satisfaction'].astype(float)

wm_subset['wm_life_satisfaction_num'].isna().sum()
# Out:
# /var/folders/v2/zgr5gbws4qd_qpb553947v7h0000gn/T/ipykernel_37129/2384192019.py:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   wm_subset['wm_life_satisfaction'] = wm_subset['wm_life_satisfaction'].replace("NO RESPONSE", np.nan)
# 75

# %% [markdown]
# **Inferenece**
#
# * `hh1` matches `w_cluster_num`
# * `hh2` matches `w_hh_num`
# * `hh3` matches `w_line_num`
#
# We can join the `wm_subset` with `hh_subset` with variables a

# %% [markdown]
# ### **Select Relevant Columns from `ch.sav` : (Under five)**
#
# * Join the children under five years day with the houshold data

# %%
# 
ch = rename_colnames_tolower(ch)

ch_cols = ["hh1", "hh2", "ln",
           # "uf1", "uf2", "uf3",
           # mother
            "uf4",
           "melevel",
           #
           "uf10",
           "survey",
           # sex
           "hl4",
           "ub2","cage","cage_6","cage_11", 
           # food groups
           "bd2", "bd3", "bd7d", "bd7e", "bd8a", "bd8b",
           "bd8c", "bd8d", "bd8e", "bd8f", "bd8g", "bd8h", 
           "bd8i", "bd8j", "bd8k", "bd8l", "bd8m", "bd8n",
           # --
           "zone", "hh6",
           "melevel", "stratum", "chweightmics" ]


ch_dicts = {
    "uf4" : "c_mother_ln",
    "melevel": "c_mother_edu_levl",
    "ub2" : "c_age_yr",
    "uf10": "consent",
    "cage": "c_age_month",
    "cage_6" : "c_age_month_cat6",
    "cage_11" : "c_age_month_cat11",
    # -- 
    "hl4" : "c_sex",
    "melevel" : "c_mother_education",
    # Food groups
    "bd2" : "c_breastfed",
    "bd3" : "c_breastfeeding",
    "bd7d" : "c_infant_formula",
    "bd7e" : "c_animal_milk",
    "bd8a" : "c_yogurt",
    "bd8b" : "c_fortified_food",
    "bd8c" : "c_grain",
    "bd8d" : "c_vitA_vegs",
    "bd8e" : "c_roots",
    "bd8f" : "c_green_leafy_vegs",
    "bd8g" : "c_vitA_fruits",
    "bd8h" : "c_other_fruits_veg",
    "bd8i" : "c_organ_meat",
    "bd8j" : "c_meat",
    "bd8k" : "c_eggs",
    "bd8l" : "c_fish",
    "bd8m" : "c_beans_pulse",
    "bd8n" : "c_cheese_f_milk",
    # location
    "hh6": "area",
}


# Create a subset of the 'ch' DataFrame, including only the columns specified in 'wm_cols'
ch_subset = ch.loc[:, ch_cols]

# Rename the columns of ch_subset using the key-value pairs in ch_dicts
ch_subset = ch_subset.rename(columns=ch_dicts)

# Filter out records where consent is not "YES"
ch_subset = ch_subset[ch_subset["consent"] == "YES"]

# Filter out records where survey is not "MICS"
ch_subset = ch_subset[ch_subset["survey"] == "MICS"].reset_index(drop=True)

# %%
ch_subset["survey"].value_counts()
# Out:
# survey
# MICS    26640
# NICS        0
# Name: count, dtype: int64

# %%
ch_subset.shape
# Out:
# (26640, 35)

# %%
ch_subset.head()
# Out:
#    hh1   hh2   ln  c_mother_ln c_mother_education consent survey   c_sex  \
# 0  1.0   3.0  4.0          2.0    Higher/tertiary     YES   MICS    MALE
# 1  1.0   3.0  5.0          2.0    Higher/tertiary     YES   MICS    MALE
# 2  1.0  10.0  5.0          2.0    Higher/tertiary     YES   MICS  FEMALE
# 3  1.0  10.0  6.0          2.0    Higher/tertiary     YES   MICS  FEMALE
# 4  1.0  15.0  6.0          2.0   Senior secondary     YES   MICS    MALE
#
#    c_age_yr  c_age_month c_age_month_cat6 c_age_month_cat11 c_breastfed  \
# 0       3.0         39.0            36-47             36-47         NaN
# 1       0.0          4.0              0-5              0-11         YES
# 2       4.0         58.0            48-59             48-59         NaN
# 3       0.0          3.0              0-5              0-11         YES
# 4       2.0         31.0            24-35             24-35         YES
#
#   c_breastfeeding c_infant_formula c_animal_milk c_yogurt c_fortified_food  \
# 0             NaN              NaN           NaN      NaN              NaN
# 1             YES              YES            NO       NO               NO
# 2             NaN              NaN           NaN      NaN              NaN
# 3             YES              YES            NO       NO              YES
# 4              NO              NaN           NaN      NaN              NaN
#
#   c_grain c_vitA_vegs c_roots c_green_leafy_vegs c_vitA_fruits  \
# 0     NaN         NaN     NaN                NaN           NaN
# 1      NO          NO      NO                 NO            NO
# 2     NaN         NaN     NaN                NaN           NaN
# 3      NO          NO      NO                 NO            NO
# 4     NaN         NaN     NaN                NaN           NaN
#
#   c_other_fruits_veg c_organ_meat c_meat c_eggs c_fish c_beans_pulse  \
# 0                NaN          NaN    NaN    NaN    NaN           NaN
# 1                 NO           NO     NO     NO     NO            NO
# 2                NaN          NaN    NaN    NaN    NaN           NaN
# 3                 NO           NO     NO     NO     NO            NO
# 4                NaN          NaN    NaN    NaN    NaN           NaN
#
#   c_cheese_f_milk        zone   area c_mother_education  stratum  chweightmics
# 0             NaN  South East  URBAN    Higher/tertiary      1.0      0.658014
# 1              NO  South East  URBAN    Higher/tertiary      1.0      0.658014
# 2             NaN  South East  URBAN    Higher/tertiary      1.0      0.658014
# 3              NO  South East  URBAN    Higher/tertiary      1.0      0.658014
# 4             NaN  South East  URBAN   Senior secondary      1.0      0.658014

# %%
# Save the children under 5 years old to MDDC folder
ch_subset.to_csv("../../MDDS/data/children_under_five.csv", index=False)

# Save household data to MDDC folder
hh_subset.to_csv("../../MDDS/data/household.csv", index=False)

# Save household data to MISC folder
hh_subset.to_csv("datasets/household.csv", index=False)

# %% [markdown]
# ### **Merging instructions**
#
# ```
# key_variables_dict = {
#     "hh1": "Cluster number",
#     "hh2": "household number",
#     "ln": "Members line number"
# }
# ```
#
#
# * We will use `HH1` and `HH2` as key variables to merge `ch_subset`, `mn_subset`, `wm_subset` with `hh_subset` dataframe

# %%
# Check the current status of our dataframes
print("shape of Household:", hh_subset.shape)
print("shape of Women(15-49 years of age):", wm_subset.shape)
print("shape of Men(15-49 years of age):", mn_subset.shape)

print("shape of Children under five:", ch_subset.shape)
# Out:
# shape of Household: (33631, 29)
# shape of Women(15-49 years of age): (38813, 20)
# shape of Men(15-49 years of age): (17347, 16)
# shape of Children under five: (26640, 35)

# %% [markdown]
# #### Merge the household dataframe with women dataframe

# %%
# Merge the hh_subset and wn_subset DataFrames on the 
# "hh1 and hh2" key.

# first sort both dataframe nu the key variables

merged_hh_wm = pd.merge(hh_subset, 
                        wm_subset, 
                        on=["hh1", "hh2"], 
                        how="left",
                       suffixes=("_hh", "_wm"))
merged_hh_wm.shape
# Out:
# (46716, 47)

# %% [markdown]
# #### Merge the household dataframe with men dataframe

# %%
merged_hh_mn = pd.merge(hh_subset, 
                        mn_subset, 
                        on=["hh1", "hh2"], 
                        how="left")


merged_hh_mn.shape
# Out:
# (38942, 43)

# %% [markdown]
# #### Merge the household dataframe with the men and women dataframe

# %%
merged_hh_wm_mn = pd.merge(merged_hh_wm, 
                           mn_subset, 
                           on=["hh1", "hh2"], 
                           how="left",
                          suffixes=("_wm", "_mn")
                          )

# %%
merged_hh_wm_mn.head(2)
# Out:
#    hh1  hh2   area state        zone consent_hh  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East        YES             4.0
# 1  1.0  1.0  URBAN  ABIA  South East        YES             4.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 3.0               0.0                0.0             1.0
#
#     hhsex  hhage  helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0  Primary            RENT           Fourth
# 1  Female   46.0  Primary            RENT           Fourth
#
#   urban_wi_quintile_mics_hh hh_agricultural_land hh_ag_land_size  \
# 0                    Middle                   NO             0.0
# 1                    Middle                   NO             0.0
#
#   hh_own_animal          water_source other_water_source  \
# 0            NO  TUBE WELL / BOREHOLE                NaN
# 1            NO  TUBE WELL / BOREHOLE                NaN
#
#   water_source_location  hhweightmics  psu  stratum_hh survey_hh  fies_score  \
# 0             ELSEWHERE       0.61955  1.0         1.0      MICS           7
# 1             ELSEWHERE       0.61955  1.0         1.0      MICS           7
#
#    hh_ls_num  ln_wm  wm_age_yrs consent_wm wm_age_cat wm_attended_sch  \
# 0          0    1.0        46.0        YES      45-49             YES
# 1          0    2.0        22.0        YES      20-24             YES
#
#   wm_level_education           welevel       wm_overall_happiness  \
# 0            PRIMARY           Primary           SOMEWHAT UNHAPPY
# 1   SENIOR SECONDARY  Senior secondary  NEITHER HAPPY NOR UNHAPPY
#
#   wm_life_satisfaction wm_life_satisfaction_last_year  \
# 0                    3                       WORSENED
# 1                    4                       WORSENED
#
#   wm_life_satisfaction_expectation survey_wm                  wm_mstatus  \
# 0                           BETTER      MICS  Currently married/in union
# 1                           BETTER      MICS      Never married/in union
#
#      wm_currently_married urban_wi_quintile_mics_wm  wmweight  stratum_wm  \
# 0  YES, CURRENTLY MARRIED                    Middle  0.631645         1.0
# 1        NO, NOT IN UNION                    Middle  0.631645         1.0
#
#    wm_life_satisfaction_num  ln_mn  mn_age_yrs mn_attended_sch mn_mstatus  \
# 0                       3.0    NaN         NaN             NaN        NaN
# 1                       4.0    NaN         NaN             NaN        NaN
#
#   mn_currently_married mn_age_cat mn_overall_happiness mn_life_satisfaction  \
# 0                  NaN        NaN                  NaN                  NaN
# 1                  NaN        NaN                  NaN                  NaN
#
#   mn_life_satisfaction_last_year mn_life_satisfaction_expectation  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
#
#   mn_education survey consent  mn_life_satisfaction_num
# 0          NaN    NaN     NaN                       NaN
# 1          NaN    NaN     NaN                       NaN

# %% [markdown]
# #### **Long Data to Wide Data**: Create a final DataFrame from `hh, women, men` DataFrames.
#
# By survey design, the `wm_subset` and `mn_subset` datasets are long format because there are multiple rows for each entity (e.g., cluster, household, household member) across different data point.
#
# Therefore the need to make each row represents a single entity, and different data point are represented by separate columns.

# %% [markdown]
# #### **Pivot the women data `wm_subset`**

# %%
# Pivot with multiple value columns
df_wm = wm_subset.pivot_table(index=['hh1', 'hh2'], columns='ln', 
                                     values=['wm_attended_sch', 'wm_age_yrs', 'welevel', 
                                             'wm_life_satisfaction_num',
                                             'wm_overall_happiness'], 
                                     aggfunc='last')

df_wm = df_wm.sort_index(axis=1, level=1)
df_wm.columns = [f'{x}_{y:,.0f}' for x,y in df_wm.columns]
df_wm = df_wm.reset_index()

# %%
print(f"The number of women surveyed(MICS) in urban area are from {df_wm.shape[0]} unique households")
# Out:
# The number of women surveyed(MICS) in urban area are from 25727 unique households

# %%
# Sanity check
# wm_subset[(wm_subset["hh1"]==576.0)&(wm_subset["hh2"]==3.0) & (wm_subset["welevel"].isin(["Senior secondary", "Higher/tertiary"]))]

# %%
# Number of women that attended any school school
# Count the number of "Yes" by row
df_wm = df_wm.assign(
    hh_wm_attended_sch_num=lambda x:(x.filter(like="wm_attended_sch")=="YES").sum(axis=1),
    hh_wm_mean_age_yrs=lambda x:(x.filter(like="wm_age_yrs")).mean(axis=1),
    hh_wm_attended_atleast_sec_sch =lambda x:(x.filter(like="welevel").isin(["Senior secondary", "Higher/tertiary"])).sum(axis=1),
    hh_wm_mean_life_satisfaction =lambda x:(x.filter(like="wm_life_satisfaction_num")).mean(axis=1),
    hh_wm_overall_happiness=lambda x:(x.filter(like="wm_overall_happiness").isin(["SOMEWHAT HAPPY","VERY HAPPY"])).sum(axis=1),
    
    
)

# %%
# # Select specific columns related to women's household data from the dataframe df_wm
# df_women = df_wm[["hh1", "hh2", "hh_wm_attended_sch_num", "hh_wm_mean_age_yrs", 
#                   "hh_wm_attended_atleast_sec_sch", "hh_wm_mean_life_satisfaction"]]


# df_women.shape

# %% [markdown]
# **Inference**
#
# * Created 4 new variables related to women in the household.
# * Select the four new created variables to added to the household data

# %% [markdown]
# #### **Pivot the Men data `mn_subset`**

# %%
# Pivot with multiple value columns
df_men = mn_subset.pivot_table(index=['hh1', 'hh2'], columns='ln', 
                                     values=['mn_attended_sch', 'mn_age_yrs', 'mn_education', 
                                             'mn_life_satisfaction_num',
                                             'mn_overall_happiness'], 
                                     aggfunc='last')

df_men = df_men.sort_index(axis=1, level=1)
df_men.columns = [f'{x}_{y:,.0f}' for x,y in df_men.columns]
df_men = df_men.reset_index()

# %%
print(f"The number of men surveyed(MICS) in urban area are from {df_men.shape[0]} unique households")
# Out:
# The number of men surveyed(MICS) in urban area are from 12036 unique households

# %%
# Number of women that attended any school school
# Count the number of "Yes" by row
df_men = df_men.assign(
    hh_mn_attended_sch_num=lambda x:(x.filter(like="mn_attended_sch")=="YES").sum(axis=1),
    hh_mn_mean_age_yrs=lambda x:(x.filter(like="mn_age_yrs")).mean(axis=1),
    hh_mn_attended_atleast_sec_sch =lambda x:(x.filter(like="mn_education").isin(["Senior secondary", "Higher/tertiary"])).sum(axis=1),
    hh_mn_mean_life_satisfaction =lambda x:(x.filter(like="mn_life_satisfaction_num")).mean(axis=1),
    hh_mn_overall_happiness=lambda x:(x.filter(like="mn_overall_happiness").isin(["SOMEWHAT HAPPY","VERY HAPPY"])).sum(axis=1),
    
)

# %% [markdown]
# **Inference**
#
# * Created 4 new variables related to adult men in the household.
# * Select the four new created variables to added to the household data

# %% [markdown]
# #### Merge the new subset dataframes to create a final dataset

# %%
merged_hh_women = pd.merge(hh_subset, df_wm, 
                            on=["hh1", "hh2"], 
                            how="left",
                            suffixes=("_hh", "_wm")
                          )
merged_hh_women.shape
# Out:
# (33631, 179)

# %% [markdown]
# ### Final Merge for Household Analysis

# %%
final_merged_df = pd.merge(merged_hh_women, df_men, 
         on=["hh1", "hh2"], 
         how="left",
         suffixes=("_hh", "_wm"))

final_merged_df.head()
# Out:
#    hh1  hh2   area state        zone consent  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East     YES             4.0
# 1  1.0  2.0  URBAN  ABIA  South East     YES             2.0
# 2  1.0  3.0  URBAN  ABIA  South East     YES             5.0
# 3  1.0  4.0  URBAN  ABIA  South East     YES             4.0
# 4  1.0  5.0  URBAN  ABIA  South East     YES             5.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 2.0               0.0                0.0             1.0
# 2                 1.0               0.0                2.0             1.0
# 3                 1.0               1.0                0.0             0.0
# 4                 1.0               0.0                0.0             1.0
#
#     hhsex  hhage           helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0           Primary            RENT           Fourth
# 1  Female   45.0  Senior secondary            RENT           Fourth
# 2    Male   41.0  Senior secondary             OWN           Fourth
# 3    Male   81.0              None             OWN           Middle
# 4    Male   63.0           Primary            RENT           Fourth
#
#   urban_wi_quintile_mics hh_agricultural_land hh_ag_land_size hh_own_animal  \
# 0                 Middle                   NO             0.0            NO
# 1                 Second                   NO             0.0            NO
# 2                 Middle                   NO             0.0           YES
# 3                Poorest                  YES             2.0           YES
# 4                 Middle                   NO             0.0            NO
#
#            water_source other_water_source water_source_location  \
# 0  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 1  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 2  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 3  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
# 4  TUBE WELL / BOREHOLE                NaN             ELSEWHERE
#
#    hhweightmics  psu  stratum survey  fies_score  hh_ls_num         welevel_1  \
# 0       0.61955  1.0      1.0   MICS           7          0           Primary
# 1       0.61955  1.0      1.0   MICS           6          0  Senior secondary
# 2       0.61955  1.0      1.0   MICS           5         30               NaN
# 3       0.61955  1.0      1.0   MICS           7        144               NaN
# 4       0.61955  1.0      1.0   MICS           7          0               NaN
#
#    wm_age_yrs_1 wm_attended_sch_1  wm_life_satisfaction_num_1  \
# 0          46.0               YES                         3.0
# 1          45.0               YES                         5.0
# 2           NaN               NaN                         NaN
# 3           NaN               NaN                         NaN
# 4           NaN               NaN                         NaN
#
#   wm_overall_happiness_1         welevel_2  wm_age_yrs_2 wm_attended_sch_2  \
# 0       SOMEWHAT UNHAPPY  Senior secondary          22.0               YES
# 1       SOMEWHAT UNHAPPY  Senior secondary          16.0               YES
# 2                    NaN   Higher/tertiary          34.0               YES
# 3                    NaN               NaN           NaN               NaN
# 4                    NaN               NaN           NaN               NaN
#
#    wm_life_satisfaction_num_2     wm_overall_happiness_2         welevel_3  \
# 0                         4.0  NEITHER HAPPY NOR UNHAPPY  Senior secondary
# 1                         6.0                 VERY HAPPY               NaN
# 2                         4.0             SOMEWHAT HAPPY               NaN
# 3                         NaN                        NaN               NaN
# 4                         NaN                        NaN  Senior secondary
#
#    wm_age_yrs_3 wm_attended_sch_3  wm_life_satisfaction_num_3  \
# 0          18.0               YES                         3.0
# 1           NaN               NaN                         NaN
# 2           NaN               NaN                         NaN
# 3           NaN               NaN                         NaN
# 4          23.0               YES                         4.0
#
#   wm_overall_happiness_3        welevel_4  wm_age_yrs_4 wm_attended_sch_4  \
# 0       SOMEWHAT UNHAPPY              NaN           NaN               NaN
# 1                    NaN              NaN           NaN               NaN
# 2                    NaN              NaN           NaN               NaN
# 3                    NaN  Higher/tertiary          38.0               YES
# 4         SOMEWHAT HAPPY              NaN           NaN               NaN
#
#    wm_life_satisfaction_num_4 wm_overall_happiness_4 welevel_5  wm_age_yrs_5  \
# 0                         NaN                    NaN       NaN           NaN
# 1                         NaN                    NaN       NaN           NaN
# 2                         NaN                    NaN       NaN           NaN
# 3                         8.0             VERY HAPPY       NaN           NaN
# 4                         NaN                    NaN       NaN           NaN
#
#   wm_attended_sch_5  wm_life_satisfaction_num_5 wm_overall_happiness_5  \
# 0               NaN                         NaN                    NaN
# 1               NaN                         NaN                    NaN
# 2               NaN                         NaN                    NaN
# 3               NaN                         NaN                    NaN
# 4               NaN                         NaN                    NaN
#
#   welevel_6  wm_age_yrs_6 wm_attended_sch_6  wm_life_satisfaction_num_6  \
# 0       NaN           NaN               NaN                         NaN
# 1       NaN           NaN               NaN                         NaN
# 2       NaN           NaN               NaN                         NaN
# 3       NaN           NaN               NaN                         NaN
# 4       NaN           NaN               NaN                         NaN
#
#   wm_overall_happiness_6 welevel_7  wm_age_yrs_7 wm_attended_sch_7  \
# 0                    NaN       NaN           NaN               NaN
# 1                    NaN       NaN           NaN               NaN
# 2                    NaN       NaN           NaN               NaN
# 3                    NaN       NaN           NaN               NaN
# 4                    NaN       NaN           NaN               NaN
#
#    wm_life_satisfaction_num_7 wm_overall_happiness_7 welevel_8  wm_age_yrs_8  \
# 0                         NaN                    NaN       NaN           NaN
# 1                         NaN                    NaN       NaN           NaN
# 2                         NaN                    NaN       NaN           NaN
# 3                         NaN                    NaN       NaN           NaN
# 4                         NaN                    NaN       NaN           NaN
#
#   wm_attended_sch_8  wm_life_satisfaction_num_8 wm_overall_happiness_8  \
# 0               NaN                         NaN                    NaN
# 1               NaN                         NaN                    NaN
# 2               NaN                         NaN                    NaN
# 3               NaN                         NaN                    NaN
# 4               NaN                         NaN                    NaN
#
#   welevel_9  wm_age_yrs_9 wm_attended_sch_9  wm_life_satisfaction_num_9  \
# 0       NaN           NaN               NaN                         NaN
# 1       NaN           NaN               NaN                         NaN
# 2       NaN           NaN               NaN                         NaN
# 3       NaN           NaN               NaN                         NaN
# 4       NaN           NaN               NaN                         NaN
#
#   wm_overall_happiness_9 welevel_10  wm_age_yrs_10 wm_attended_sch_10  \
# 0                    NaN        NaN            NaN                NaN
# 1                    NaN        NaN            NaN                NaN
# 2                    NaN        NaN            NaN                NaN
# 3                    NaN        NaN            NaN                NaN
# 4                    NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_10 wm_overall_happiness_10 welevel_11  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_11 wm_attended_sch_11  wm_life_satisfaction_num_11  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_11 welevel_12  wm_age_yrs_12 wm_attended_sch_12  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_12 wm_overall_happiness_12 welevel_13  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_13 wm_attended_sch_13  wm_life_satisfaction_num_13  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_13 welevel_14  wm_age_yrs_14 wm_attended_sch_14  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_14 wm_overall_happiness_14 welevel_15  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_15 wm_attended_sch_15  wm_life_satisfaction_num_15  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_15 welevel_16  wm_age_yrs_16 wm_attended_sch_16  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_16 wm_overall_happiness_16 welevel_17  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_17 wm_attended_sch_17  wm_life_satisfaction_num_17  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_17 welevel_18  wm_age_yrs_18 wm_attended_sch_18  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_18 wm_overall_happiness_18 welevel_19  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_19 wm_attended_sch_19  wm_life_satisfaction_num_19  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_19 welevel_20  wm_age_yrs_20 wm_attended_sch_20  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_20 wm_overall_happiness_20 welevel_21  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_21 wm_attended_sch_21  wm_life_satisfaction_num_21  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_21 welevel_22  wm_age_yrs_22 wm_attended_sch_22  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_22 wm_overall_happiness_22 welevel_23  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_23 wm_attended_sch_23  wm_life_satisfaction_num_23  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_23 welevel_24  wm_age_yrs_24 wm_attended_sch_24  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_24 wm_overall_happiness_24 welevel_25  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_25 wm_attended_sch_25  wm_life_satisfaction_num_25  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_25 welevel_26  wm_age_yrs_26 wm_attended_sch_26  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_26 wm_overall_happiness_26 welevel_27  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_27 wm_attended_sch_27  wm_life_satisfaction_num_27  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_27 welevel_28  wm_age_yrs_28 wm_attended_sch_28  \
# 0                     NaN        NaN            NaN                NaN
# 1                     NaN        NaN            NaN                NaN
# 2                     NaN        NaN            NaN                NaN
# 3                     NaN        NaN            NaN                NaN
# 4                     NaN        NaN            NaN                NaN
#
#    wm_life_satisfaction_num_28 wm_overall_happiness_28 welevel_32  \
# 0                          NaN                     NaN        NaN
# 1                          NaN                     NaN        NaN
# 2                          NaN                     NaN        NaN
# 3                          NaN                     NaN        NaN
# 4                          NaN                     NaN        NaN
#
#    wm_age_yrs_32 wm_attended_sch_32  wm_life_satisfaction_num_32  \
# 0            NaN                NaN                          NaN
# 1            NaN                NaN                          NaN
# 2            NaN                NaN                          NaN
# 3            NaN                NaN                          NaN
# 4            NaN                NaN                          NaN
#
#   wm_overall_happiness_32  hh_wm_attended_sch_num  hh_wm_mean_age_yrs  \
# 0                     NaN                     3.0           28.666667
# 1                     NaN                     2.0           30.500000
# 2                     NaN                     1.0           34.000000
# 3                     NaN                     1.0           38.000000
# 4                     NaN                     1.0           23.000000
#
#    hh_wm_attended_atleast_sec_sch  hh_wm_mean_life_satisfaction  \
# 0                             2.0                      3.333333
# 1                             2.0                      5.500000
# 2                             1.0                      4.000000
# 3                             1.0                      8.000000
# 4                             1.0                      4.000000
#
#    hh_wm_overall_happiness  mn_age_yrs_1 mn_attended_sch_1 mn_education_1  \
# 0                      0.0           NaN               NaN            NaN
# 1                      1.0           NaN               NaN            NaN
# 2                      1.0           NaN               NaN            NaN
# 3                      1.0           NaN               NaN            NaN
# 4                      1.0           NaN               NaN            NaN
#
#    mn_life_satisfaction_num_1 mn_overall_happiness_1  mn_age_yrs_2  \
# 0                         NaN                    NaN           NaN
# 1                         NaN                    NaN           NaN
# 2                         NaN                    NaN           NaN
# 3                         NaN                    NaN           NaN
# 4                         NaN                    NaN           NaN
#
#   mn_attended_sch_2 mn_education_2  mn_life_satisfaction_num_2  \
# 0               NaN            NaN                         NaN
# 1               NaN            NaN                         NaN
# 2               NaN            NaN                         NaN
# 3               NaN            NaN                         NaN
# 4               NaN            NaN                         NaN
#
#   mn_overall_happiness_2  mn_age_yrs_3 mn_attended_sch_3   mn_education_3  \
# 0                    NaN           NaN               NaN              NaN
# 1                    NaN           NaN               NaN              NaN
# 2                    NaN           NaN               NaN              NaN
# 3                    NaN          33.0               YES  Higher/tertiary
# 4                    NaN           NaN               NaN              NaN
#
#    mn_life_satisfaction_num_3     mn_overall_happiness_3  mn_age_yrs_4  \
# 0                         NaN                        NaN           NaN
# 1                         NaN                        NaN           NaN
# 2                         NaN                        NaN           NaN
# 3                         5.0  NEITHER HAPPY NOR UNHAPPY           NaN
# 4                         NaN                        NaN           NaN
#
#   mn_attended_sch_4 mn_education_4  mn_life_satisfaction_num_4  \
# 0               NaN            NaN                         NaN
# 1               NaN            NaN                         NaN
# 2               NaN            NaN                         NaN
# 3               NaN            NaN                         NaN
# 4               NaN            NaN                         NaN
#
#   mn_overall_happiness_4  mn_age_yrs_5 mn_attended_sch_5 mn_education_5  \
# 0                    NaN           NaN               NaN            NaN
# 1                    NaN           NaN               NaN            NaN
# 2                    NaN           NaN               NaN            NaN
# 3                    NaN           NaN               NaN            NaN
# 4                    NaN           NaN               NaN            NaN
#
#    mn_life_satisfaction_num_5 mn_overall_happiness_5  mn_age_yrs_6  \
# 0                         NaN                    NaN           NaN
# 1                         NaN                    NaN           NaN
# 2                         NaN                    NaN           NaN
# 3                         NaN                    NaN           NaN
# 4                         NaN                    NaN           NaN
#
#   mn_attended_sch_6 mn_education_6  mn_life_satisfaction_num_6  \
# 0               NaN            NaN                         NaN
# 1               NaN            NaN                         NaN
# 2               NaN            NaN                         NaN
# 3               NaN            NaN                         NaN
# 4               NaN            NaN                         NaN
#
#   mn_overall_happiness_6  mn_age_yrs_7 mn_attended_sch_7 mn_education_7  \
# 0                    NaN           NaN               NaN            NaN
# 1                    NaN           NaN               NaN            NaN
# 2                    NaN           NaN               NaN            NaN
# 3                    NaN           NaN               NaN            NaN
# 4                    NaN           NaN               NaN            NaN
#
#    mn_life_satisfaction_num_7 mn_overall_happiness_7  mn_age_yrs_8  \
# 0                         NaN                    NaN           NaN
# 1                         NaN                    NaN           NaN
# 2                         NaN                    NaN           NaN
# 3                         NaN                    NaN           NaN
# 4                         NaN                    NaN           NaN
#
#   mn_attended_sch_8 mn_education_8  mn_life_satisfaction_num_8  \
# 0               NaN            NaN                         NaN
# 1               NaN            NaN                         NaN
# 2               NaN            NaN                         NaN
# 3               NaN            NaN                         NaN
# 4               NaN            NaN                         NaN
#
#   mn_overall_happiness_8  mn_age_yrs_9 mn_attended_sch_9 mn_education_9  \
# 0                    NaN           NaN               NaN            NaN
# 1                    NaN           NaN               NaN            NaN
# 2                    NaN           NaN               NaN            NaN
# 3                    NaN           NaN               NaN            NaN
# 4                    NaN           NaN               NaN            NaN
#
#    mn_life_satisfaction_num_9 mn_overall_happiness_9  mn_age_yrs_10  \
# 0                         NaN                    NaN            NaN
# 1                         NaN                    NaN            NaN
# 2                         NaN                    NaN            NaN
# 3                         NaN                    NaN            NaN
# 4                         NaN                    NaN            NaN
#
#   mn_attended_sch_10 mn_education_10  mn_life_satisfaction_num_10  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_10  mn_age_yrs_11 mn_attended_sch_11 mn_education_11  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_11 mn_overall_happiness_11  mn_age_yrs_12  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_12 mn_education_12  mn_life_satisfaction_num_12  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_12  mn_age_yrs_13 mn_attended_sch_13 mn_education_13  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_13 mn_overall_happiness_13  mn_age_yrs_14  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_14 mn_education_14  mn_life_satisfaction_num_14  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_14  mn_age_yrs_15 mn_attended_sch_15 mn_education_15  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_15 mn_overall_happiness_15  mn_age_yrs_16  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_16 mn_education_16  mn_life_satisfaction_num_16  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_16  mn_age_yrs_17 mn_attended_sch_17 mn_education_17  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_17 mn_overall_happiness_17  mn_age_yrs_18  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_18 mn_education_18  mn_life_satisfaction_num_18  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_18  mn_age_yrs_19 mn_attended_sch_19 mn_education_19  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_19 mn_overall_happiness_19  mn_age_yrs_20  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_20 mn_education_20  mn_life_satisfaction_num_20  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_20  mn_age_yrs_21 mn_attended_sch_21 mn_education_21  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_21 mn_overall_happiness_21  mn_age_yrs_22  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_22 mn_education_22  mn_life_satisfaction_num_22  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_22  mn_age_yrs_23 mn_attended_sch_23 mn_education_23  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_23 mn_overall_happiness_23  mn_age_yrs_24  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_24 mn_education_24  mn_life_satisfaction_num_24  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_24  mn_age_yrs_25 mn_attended_sch_25 mn_education_25  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_25 mn_overall_happiness_25  mn_age_yrs_26  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_26 mn_education_26  mn_life_satisfaction_num_26  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_26  mn_age_yrs_27 mn_attended_sch_27 mn_education_27  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_27 mn_overall_happiness_27  mn_age_yrs_28  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_28 mn_education_28  mn_life_satisfaction_num_28  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_28  mn_age_yrs_29 mn_attended_sch_29 mn_education_29  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
#
#    mn_life_satisfaction_num_29 mn_overall_happiness_29  mn_age_yrs_30  \
# 0                          NaN                     NaN            NaN
# 1                          NaN                     NaN            NaN
# 2                          NaN                     NaN            NaN
# 3                          NaN                     NaN            NaN
# 4                          NaN                     NaN            NaN
#
#   mn_attended_sch_30 mn_education_30  mn_life_satisfaction_num_30  \
# 0                NaN             NaN                          NaN
# 1                NaN             NaN                          NaN
# 2                NaN             NaN                          NaN
# 3                NaN             NaN                          NaN
# 4                NaN             NaN                          NaN
#
#   mn_overall_happiness_30  hh_mn_attended_sch_num  hh_mn_mean_age_yrs  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                     NaN                     NaN                 NaN
# 3                     NaN                     1.0                33.0
# 4                     NaN                     NaN                 NaN
#
#    hh_mn_attended_atleast_sec_sch  hh_mn_mean_life_satisfaction  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             1.0                           5.0
# 4                             NaN                           NaN
#
#    hh_mn_overall_happiness
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      0.0
# 4                      NaN

# %%
# Final variables of interest for household level analysis
final_cols = ["hh1","hh2", 
              "area", "zone", 
              "hh_members_num", 

              "num_of_women_15_49", "num_of_men_15_49",
              "num_under_5_child", "num_5_17_child",
              "hhsex", 
              "hhage", 
              "helevel",
              "hh_own_dwelling",
              
              # ====survey weights
              "wi_quintile_mics",
              "urban_wi_quintile_mics",
              
              # ====Agricultural variables
              "hh_agricultural_land",
              "hh_ag_land_size",
              "hh_own_animal", # own livestock

              # ====water
              "water_source",
              "other_water_source",
              "water_source_location",

              # === survey design parameters
              "hhweightmics",
              "psu",
              "stratum",

              # === calculated livestock num and FIES
              "hh_ls_num",
              "fies_score",
              #========Women in household =======#
              # Number of women who attended school
              "hh_wm_attended_sch_num",
              # Average age of women
              "hh_wm_mean_age_yrs",
              # Number of women that attended at least secondary education
              "hh_wm_attended_atleast_sec_sch",
              # Average life satisfaction of women in hh
              "hh_wm_mean_life_satisfaction",

              # ===========Men in the household
              # Number of men who attended school
              "hh_mn_attended_sch_num",
              # average age of men
              "hh_mn_mean_age_yrs",
              # Number of men who attended at least secodn
              "hh_mn_attended_atleast_sec_sch",
              # Average life satisfaction of men in hh
              "hh_mn_mean_life_satisfaction"
             ]

len(final_cols)
# Out:
# 34

# %%
df = final_merged_df[final_cols]

# Save to csv
df.to_csv("datasets/final_df_household_fies.csv")

# %%
#Sanity Check: Filter the dataframe merged_hh_wm_mn to include only rows where hh1 is 1.0 and hh2 is 2.0
merged_hh_wm_mn[(merged_hh_wm_mn["hh1"] == 1.0) & (merged_hh_wm_mn["hh2"] == 1.0)]
# Out:
#    hh1  hh2   area state        zone consent_hh  hh_members_num  \
# 0  1.0  1.0  URBAN  ABIA  South East        YES             4.0
# 1  1.0  1.0  URBAN  ABIA  South East        YES             4.0
# 2  1.0  1.0  URBAN  ABIA  South East        YES             4.0
#
#    num_of_women_15_49  num_of_men_15_49  num_under_5_child  num_5_17_child  \
# 0                 3.0               0.0                0.0             1.0
# 1                 3.0               0.0                0.0             1.0
# 2                 3.0               0.0                0.0             1.0
#
#     hhsex  hhage  helevel hh_own_dwelling wi_quintile_mics  \
# 0  Female   46.0  Primary            RENT           Fourth
# 1  Female   46.0  Primary            RENT           Fourth
# 2  Female   46.0  Primary            RENT           Fourth
#
#   urban_wi_quintile_mics_hh hh_agricultural_land hh_ag_land_size  \
# 0                    Middle                   NO             0.0
# 1                    Middle                   NO             0.0
# 2                    Middle                   NO             0.0
#
#   hh_own_animal          water_source other_water_source  \
# 0            NO  TUBE WELL / BOREHOLE                NaN
# 1            NO  TUBE WELL / BOREHOLE                NaN
# 2            NO  TUBE WELL / BOREHOLE                NaN
#
#   water_source_location  hhweightmics  psu  stratum_hh survey_hh  fies_score  \
# 0             ELSEWHERE       0.61955  1.0         1.0      MICS           7
# 1             ELSEWHERE       0.61955  1.0         1.0      MICS           7
# 2             ELSEWHERE       0.61955  1.0         1.0      MICS           7
#
#    hh_ls_num  ln_wm  wm_age_yrs consent_wm wm_age_cat wm_attended_sch  \
# 0          0    1.0        46.0        YES      45-49             YES
# 1          0    2.0        22.0        YES      20-24             YES
# 2          0    3.0        18.0        YES      15-19             YES
#
#   wm_level_education           welevel       wm_overall_happiness  \
# 0            PRIMARY           Primary           SOMEWHAT UNHAPPY
# 1   SENIOR SECONDARY  Senior secondary  NEITHER HAPPY NOR UNHAPPY
# 2   SENIOR SECONDARY  Senior secondary           SOMEWHAT UNHAPPY
#
#   wm_life_satisfaction wm_life_satisfaction_last_year  \
# 0                    3                       WORSENED
# 1                    4                       WORSENED
# 2                    3                       WORSENED
#
#   wm_life_satisfaction_expectation survey_wm                  wm_mstatus  \
# 0                           BETTER      MICS  Currently married/in union
# 1                           BETTER      MICS      Never married/in union
# 2            MORE OR LESS THE SAME      MICS      Never married/in union
#
#      wm_currently_married urban_wi_quintile_mics_wm  wmweight  stratum_wm  \
# 0  YES, CURRENTLY MARRIED                    Middle  0.631645         1.0
# 1        NO, NOT IN UNION                    Middle  0.631645         1.0
# 2        NO, NOT IN UNION                    Middle  0.631645         1.0
#
#    wm_life_satisfaction_num  ln_mn  mn_age_yrs mn_attended_sch mn_mstatus  \
# 0                       3.0    NaN         NaN             NaN        NaN
# 1                       4.0    NaN         NaN             NaN        NaN
# 2                       3.0    NaN         NaN             NaN        NaN
#
#   mn_currently_married mn_age_cat mn_overall_happiness mn_life_satisfaction  \
# 0                  NaN        NaN                  NaN                  NaN
# 1                  NaN        NaN                  NaN                  NaN
# 2                  NaN        NaN                  NaN                  NaN
#
#   mn_life_satisfaction_last_year mn_life_satisfaction_expectation  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
#
#   mn_education survey consent  mn_life_satisfaction_num
# 0          NaN    NaN     NaN                       NaN
# 1          NaN    NaN     NaN                       NaN
# 2          NaN    NaN     NaN                       NaN

# %%
final_merged_df.shape
# Out:
# (33631, 334)

# %% [markdown]
# ### Life Satisfaction and Overall Happiness (Urban)
#
# * Happiness and life satisfaction at household level
# * Happiness and life satisfaction at women level
# * Happiness and life satisfaction at men level

# %%
# Men Happiness and life satisfaction
mn_happ_cols = ["hh1", "hh2","hh6", "hh7","zone",
           "ln",
           "mwb4", "mwb5",
           "mmstatus","mma1",
           "mwage",
           "mls1", "mls2", "mls3", "mls4",
           "mwelevel","windex5",
           "survey", "mwm9",
          "mnweight"]

mn_happ_dict = {
    "mwm9": "consent",
    "mls1": "mn_overall_happiness",
    "mls2": "mn_life_satisfaction",
    "mls3": "mn_life_satisfaction_last_year",
    "mls4": "mn_life_satisfaction_expectation",
    "mwb5": "mn_attended_sch",
    "mwelevel": "mn_education",
    "mmstatus": "mn_mstatus",
    "mwb4": "mn_age_yrs",
    
}


df_mn_happiness = mn[mn_happ_cols]

# Rename the columns of wm_subset using the key-value pairs in wm_dicts
df_mn_happiness = df_mn_happiness.rename(columns=mn_happ_dict)
# Save dataframe women level
df_mn_happiness.to_csv("datasets/men_level_happiness.csv", index=False)

# %%
# Women happiness and life satisfaction
wm_happ_cols = ["hh1", "hh2","hh6", "hh7", "zone", "ln",
           "wb4", "wm9",
           "wage", "wb5", "wb6a","welevel", 
           "ls1","ls2","ls3","ls4",
           "survey", "mstatus", 
           "windex5u",
           "wmweight", "stratum"]

wm_happ_dicts  = {
    "wb4": "wm_age_yrs",
    "wm9": "consent",
    "ls1": "wm_overall_happiness",
    "ls2": "wm_life_satisfaction",
    "ls3": "wm_life_satisfaction_last_year",
    "ls4": "wm_life_satisfaction_expectation",
    "wage": "wm_age_cat",
    "wb5": "wm_attended_sch",
    "wb6a": "wm_level_education",
    "mstatus": "wm_mstatus",
     # Wealth index
    "windex5": "wi_quintile_mics",

}


df_wm_happiness = wm.loc[:, wm_cols]

# Rename the columns of wm_subset using the key-value pairs in wm_dicts
df_wm_happiness = df_wm_happiness.rename(columns=wm_happ_dicts)

# Save dataframe men level
df_wm_happiness.to_csv("datasets/women_level_happiness.csv", index=False)

# %%
# Women happiness and life satisfaction
wm_happ_cols = ["hh1", "hh2","hh6", "hh7", "zone", "ln",
           "wb4", "wm9",
           "wage", "wb5", "wb6a","welevel", 
           "ls1","ls2","ls3","ls4",
           "survey", "mstatus", 
           "windex5u",
           "wmweight", "stratum"]

wm_happ_dicts  = {
    "wb4": "wm_age_yrs",
    "wm9": "consent",
    "ls1": "wm_overall_happiness",
    "ls2": "wm_life_satisfaction",
    "ls3": "wm_life_satisfaction_last_year",
    "ls4": "wm_life_satisfaction_expectation",
    "wage": "wm_age_cat",
    "wb5": "wm_attended_sch",
    "wb6a": "wm_level_education",
    "mstatus": "wm_mstatus",
     # Wealth index
    "windex5": "wi_quintile_mics",

}


df_wm_happiness = wm.loc[:, wm_cols]

# Rename the columns of wm_subset using the key-value pairs in wm_dicts
df_wm_happiness = df_wm_happiness.rename(columns=wm_happ_dicts)

# Save dataframe men level
df_wm_happiness.to_csv("datasets/women_level_happiness.csv", index=False)

# %%
# Household level happiness and life expectancy

happiness_cols = ["hh1","hh2", 
                  "area", "zone", "state",
                  "hh_members_num",
                  "hhsex", 
                  "hhage", 
                  "helevel",
                  
                 "wi_quintile_mics",
                  "urban_wi_quintile_mics",
                  "fies_score",
                  "hh_mn_mean_age_yrs",
                   "hh_wm_mean_age_yrs",
                  "hh_mn_mean_life_satisfaction",
                  "hh_mn_overall_happiness",
                  "hh_wm_mean_life_satisfaction",
                  "hh_wm_overall_happiness"
                 ]

df_hh_happiness  = final_merged_df[happiness_cols]

# Save dataframe hh level
df_hh_happiness.to_csv("datasets/hh_level_happiness.csv", index=False)

# %%
# Create a list of column names related to men's household data 
# mn_cols = ["hh1", "hh2", "hh_mn_attended_sch_num", "hh_mn_mean_age_yrs", 
#  "hh_mn_attended_atleast_sec_sch", "hh_mn_mean_life_satisfaction"]


# # Create a list of column names related to men's household data 
# wm_cols = ["hh1", "hh2", "hh_wm_attended_sch_num", "hh_wm_mean_age_yrs",
#            "hh_wm_attended_atleast_sec_sch", "hh_wm_mean_life_satisfaction"]

# merged_mn_wm_cols = mn_cols + wm_cols

# %% [markdown]
# ### Data Pre-processing Pipeline
